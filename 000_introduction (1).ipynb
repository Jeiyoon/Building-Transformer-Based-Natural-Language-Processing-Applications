# %% [markdown]
# ![DLI_Header.png](data:image/png;base64,...)

# %% [markdown]
# # Transformer 기반 자연어 처리 애플리케이션 구축
# ### 1부: Machine Learning in NLP
#
# 이 랩에서는 *Attention*의 개념을 살펴보고 ["Attention is All You Need!"(Vaswani 외, 2017년)](https://arxiv.org/abs/1706.03762) 논문에서 소개된 Attention이 Transformer 아키텍처를 구성하는 방식에 대해 알아봅니다. Transformer 아키텍처는 [BERT](https://arxiv.org/abs/1810.04805)(Bidirectional Encoder Representations from Transformers) 및 [Megatron](https://developer.nvidia.com/blog/language-modeling-using-megatron-a100-gpu/)과 같은 대규모 언어 모델에 대한 선구적 개념으로, NLP(자연어 처리) 작업의 정확도를 크게 높였으며 여러 산업 전반의 기업들이 고품질 언어 기반 서비스를 접할 수 있게 했습니다.
#
# 이 섹션에서 초점을 맞출 특정 NLP 작업은 *NMT(Neural Machine Translation)*입니다.  Transformer 아키텍처의 기초를 단계별로 살펴보고 이를 사용해 영어 문장을 독일어 문장으로 번역해 보겠습니다.
#
#
# ![enc_dec.png](data:image/png;base64,...)
#
#
# 이 노트북 전체에서는 NVIDIA [DeepLearningExamples](https://github.com/NVIDIA/DeepLearningExamples/tree/master/PyTorch/Translation/Transformer) Transformer GitHub 리포지토리를 사용할 것입니다. 전체 사용 가이드는 리포지토리 README를 참조하십시오.

# %% [markdown]
# ## 목차
#
# 1. Transformer 아키텍처가 NMT에 가져온 변화<br>
#     Transformer 아키텍처의 핵심은 Attention 입니다...<br>
#     학습 내용:
#     - Neural Machine Translation
#     - Transformer 아키텍처
#     - Attention
#     - Transformer 모델
# <br><br>
# 1. 인코더<br>
#     학습 내용:
#     - 인코더 메커니즘
#     - 임베딩
#     - Positional Encoding
#     - Multi-head Attention
# <br><br>
# 1. 디코더<br>
#     학습 내용:
#     - 디코더 메커니즘
#     - Masked Multi-head Attention

# %% [markdown]
# 아래 셀에서 간단한 출력 문을 실행해 보십시오.

# %%
# Highlight this cell and click [Shift+Enter] to execute
print('This is just a simple print statement')
# Out:
# This is just a simple print statement

# %% [markdown]
# ![DLI_Header.png](data:image/png;base64,...)
